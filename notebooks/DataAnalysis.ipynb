# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
import pickle
# %matplotlib notebook

# %%
file_name = 'nonlins1'
fileObject2 = open(file_name,'rb');
length = 5
array = []
for i in range(0,length):
    array.append(pickle.load(fileObject2));
fileObject2.close()

# %%
array[0][1];
# Model description: "Model with {} activation, {} hidden layers and {} weight init".format
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-537ebe76dc4a> in <module>()
# ----> 1 array[0][1];
#       2 # Model description: "Model with {} activation, {} hidden layers and {} weight init".format
#
# NameError: name 'array' is not defined

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
subarray = array[0:2]
for net in subarray:
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(valid)']], label=net[0])
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], label=net[0])
    axs[0].set_ylabel('Error')
    axs[0].legend()
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(valid)']], label=net[0])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']], label=net[0])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
relu = np.min(array[0][1][0][1:, net[1][1]['error(valid)']])
sigmoid = np.min(array[1][1][0][1:, net[1][1]['error(valid)']])
relu2 = np.min(array[2][1][0][1:, net[1][1]['error(valid)']])
relu3 = np.min(array[3][1][0][1:, net[1][1]['error(valid)']])
relu4 = np.min(array[4][1][0][1:, net[1][1]['error(valid)']])

(sigmoid, relu, relu2, relu3, relu4)
# Out:
# (0.085808546107419781,
#  0.086169328382585203,
#  0.087003873168987222,
#  0.08743512205255391,
#  0.090196624390888894)

# %%
relu = np.min(array[0][1][0][1:, net[1][1]['acc(valid)']])
sigmoid = np.min(array[1][1][0][1:, net[1][1]['acc(valid)']])
relu2 = np.min(array[2][1][0][1:, net[1][1]['acc(valid)']])
relu3 = np.min(array[3][1][0][1:, net[1][1]['acc(valid)']])
relu4 = np.min(array[4][1][0][1:, net[1][1]['acc(valid)']])

(sigmoid, relu, relu2, relu3, relu4)
# Out:
# (0.93410000000000037,
#  0.96479999999999966,
#  0.96419999999999983,
#  0.95929999999999993,
#  0.95849999999999946)

# %%
file_name = 'hiddenLayers'
fileObject = open(file_name,'rb');
length = 21
array2 = []
for i in range(0,length):
    array2.append(pickle.load(fileObject));
fileObject.close()

sigmoids = array2[0:7]
leakyRelu = array2[7:14]
selu = array2[14:21]
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# ...

# %%
plt.close("all")

# %%
leakyRelu
# Out:
# [((LeakyReluLayer, 2, 'uniform'),
#   (array([[  2.40088858e+00,   9.52800000e-02,   2.40511663e+00,
#              9.69000000e-02,   0.00000000e+00],
#           [  1.30950836e-01,   9.61140000e-01,   1.35286471e-01,
#              9.60600000e-01,   0.00000000e+00],
#           [  8.11340874e-02,   9.75800000e-01,   9.71443092e-02,
#              9.70500000e-01,   0.00000000e+00],
#           [  6.09795652e-02,   9.82400000e-01,   9.20499083e-02,
#              9.73300000e-01,   0.00000000e+00],
#           [  4.61553703e-02,   9.86220000e-01,   8.72500312e-02,
#              9.73300000e-01,   0.00000000e+00],
#           [  3.44440400e-02,   9.91140000e-01,   8.47160483e-02,
#              9.76000000e-01,   0.00000000e+00],
#           [  2.91925087e-02,   9.91560000e-01,   8.79536206e-02,
#              9.76100000e-01,   0.00000000e+00],
#           [  2.29176016e-02,   9.94020000e-01,   8.58648672e-02,
#              9.75500000e-01,   0.00000000e+00],
# ...

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
subarray = leakyRelu
for net in subarray:
#     axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(valid)']], label=net[0])
#     axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], label=net[0])
    axs[0].set_ylabel('Acc(test)')
    axs[0].legend()
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(valid)']])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(train)']], label=net[0][1])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/miro/.conda/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
