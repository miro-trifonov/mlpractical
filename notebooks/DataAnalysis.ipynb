# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
import pickle
# %matplotlib notebook

# %%
file_name = 'exp_bathch_norm'
file_name2 = 'exp_bathch_norm_2'
fileObject2 = open(file_name,'rb');
fileObject3 = open(file_name2,'rb');
length = 2
array = []
for i in range(0,length):
    array.append(pickle.load(fileObject2));
for i in range(0,length):
    array.append(pickle.load(fileObject3));
fileObject2.close()
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">

# %%
array[0][1];

# %%
fig, axs = plt.subplots(1, 1, figsize=(8,4))
# subarray = [array[1]] + [array[3]]
i = 0
this = ["Learning rate: 0.1, RELU","Learning rate: 0.01, RELU","Learning rate: 0.1, ELU","Learning rate: 0.01, ELU"]
for net in array:
#     axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], )
#     axs[0].plot(np.arange(1, net[1][0].shape[0])*2, net[1][0][1:, net[1][1]['acc(train)']],label=(this[i]))
#     axs[0].set_ylabel('Accuracy(train)')
#     axs[0].legend()
#     axs[2].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']])
    axs.plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(valid)']],label=(this[i]))
    axs.set_xlabel('Epochs')
    axs.set_ylabel('Accuracy(valid)')
    axs.legend()
    i+= 1
    plt.savefig('{0}.pdf'.format("norm_2"))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
relu = np.max(array[0][1][0][1:, net[1][1]['acc(valid)']])
sigmoid = np.max(array[1][1][0][1:, net[1][1]['acc(valid)']])
relu2 = np.max(array[2][1][0][1:, net[1][1]['acc(valid)']])
relu3 = np.max(array[3][1][0][1:, net[1][1]['acc(valid)']])
# relu4 = np.max(array[6][1][0][1:, net[1][1]['acc(valid)']])

(sigmoid, relu, relu2,relu3)
# Out:
# (0.84082278481012651,
#  0.83727848101265834,
#  0.83341772151898741,
#  0.83449367088607607)
