# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
import pickle
# %matplotlib notebook

# %%
file_name = 'nonlins1'
fileObject2 = open(file_name,'rb');
length = 5
array = []
for i in range(0,length):
    array.append(pickle.load(fileObject2));
fileObject2.close()
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">

# %%
array[0][1];
# Model description: "Model with {} activation, {} hidden layers and {} weight init".format

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
subarray = [array[0]]+ array[3:5]
i = 0
this = ["ReLU model, two hidden layers","Sigmoid model, 2 hidden layers"]
for net in subarray:
#     axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], )
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(valid)']],label=net[0])
    axs[0].set_ylabel('Error')
    axs[0].legend()
#     axs[2].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(valid)']])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
    i+= 1
    plt.savefig('{0}.pdf'.format("lreluVsSeLU"))
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/miro/.conda/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
relu = np.max(array[0][1][0][1:, net[1][1]['acc(valid)']])
sigmoid = np.max(array[1][1][0][1:, net[1][1]['acc(valid)']])
relu2 = np.max(array[2][1][0][1:, net[1][1]['acc(valid)']])
relu3 = np.max(array[3][1][0][1:, net[1][1]['acc(valid)']])
relu4 = np.max(array[4][1][0][1:, net[1][1]['acc(valid)']])

(sigmoid, relu, relu2, relu3, relu4)
# Out:
# (0.97569999999999968,
#  0.97799999999999954,
#  0.97789999999999955,
#  0.97769999999999957,
#  0.97599999999999953)

# %%
file_name = 'hiddenLayers'
fileObject = open(file_name,'rb');
length = 21
array2 = []
for i in range(0,length):
    array2.append(pickle.load(fileObject));
fileObject.close()

sigmoids = array2[0:7]
leakyRelu = array2[7:14]
selu = array2[14:21]
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# ...

# %%
plt.close("all")

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
subarray = leakyRelu
for net in subarray:
#     axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(valid)']], label=net[0])
#     axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], label=net[0])
    axs[0].set_ylabel('Accuracy(train)')
    axs[0].legend()
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(train)']])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(valid)']], label=net[0][1])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy(test)')
    axs[1].legend()
plt.savefig('{0}.pdf'.format("lreluHiddenLayers"))
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/miro/.conda/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
np.max(leakyRelu[1][1][0][1:, net[1][1]['acc(valid)']])
# Out:
# 0.98119999999999929
