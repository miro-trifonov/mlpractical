# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
import pickle
# %matplotlib notebook

# %%
file_name = 'nonlins1'
fileObject2 = open(file_name,'rb');
length = 5
array = []
for i in range(0,length):
    array.append(pickle.load(fileObject2));
fileObject2.close()

# %%
array[0][1]
# Model description: "Model with {} activation, {} hidden layers and {} weight init".format
# Out:
# (array([[  2.40115282e+00,   9.55400000e-02,   2.40542182e+00,
#            9.79000000e-02,   0.00000000e+00],
#         [  1.15229780e-01,   9.66120000e-01,   1.25752694e-01,
#            9.64800000e-01,   0.00000000e+00],
#         [  6.76673349e-02,   9.80280000e-01,   9.79443359e-02,
#            9.71600000e-01,   0.00000000e+00],
#         [  4.35278103e-02,   9.87880000e-01,   8.65102170e-02,
#            9.74200000e-01,   0.00000000e+00],
#         [  3.21295385e-02,   9.91340000e-01,   8.61693284e-02,
#            9.74300000e-01,   0.00000000e+00],
#         [  2.11153496e-02,   9.94840000e-01,   9.00665001e-02,
#            9.75900000e-01,   0.00000000e+00],
#         [  1.41137894e-02,   9.97560000e-01,   8.86850479e-02,
#            9.76400000e-01,   0.00000000e+00],
#         [  1.16162374e-02,   9.98100000e-01,   9.56922738e-02,
#            9.75800000e-01,   0.00000000e+00],
#         [  7.54679959e-03,   9.99040000e-01,   9.62981894e-02,
#            9.76600000e-01,   0.00000000e+00],
#         [  5.36574321e-03,   9.99700000e-01,   9.84896317e-02,
#            9.76800000e-01,   0.00000000e+00],
#         [  4.26254280e-03,   9.99760000e-01,   1.01639576e-01,
#            9.77000000e-01,   0.00000000e+00],
#         [  3.16749563e-03,   9.99940000e-01,   1.05619603e-01,
#            9.77500000e-01,   0.00000000e+00],
#         [  2.64193364e-03,   9.99920000e-01,   1.07316339e-01,
#            9.77400000e-01,   0.00000000e+00],
#         [  2.16628970e-03,   9.99980000e-01,   1.09637854e-01,
#            9.78000000e-01,   0.00000000e+00],
#         [  1.94116322e-03,   1.00000000e+00,   1.12030669e-01,
#            9.77600000e-01,   0.00000000e+00],
#         [  1.71355073e-03,   9.99980000e-01,   1.14520833e-01,
#            9.77800000e-01,   0.00000000e+00],
#         [  1.46280198e-03,   1.00000000e+00,   1.16515271e-01,
#            9.77900000e-01,   0.00000000e+00],
#         [  1.25990963e-03,   1.00000000e+00,   1.17804201e-01,
#            9.78000000e-01,   0.00000000e+00],
#         [  1.15867611e-03,   1.00000000e+00,   1.20237225e-01,
#            9.77800000e-01,   0.00000000e+00],
#         [  1.03537639e-03,   1.00000000e+00,   1.21583900e-01,
#            9.78000000e-01,   0.00000000e+00],
#         [  9.42857863e-04,   1.00000000e+00,   1.22777915e-01,
#            9.77900000e-01,   0.00000000e+00]]),
#  {'acc(train)': 1,
#   'acc(valid)': 3,
#   'error(train)': 0,
#   'error(valid)': 2,
#   'params_penalty': 4},
#  62.512699604034424,
#  <matplotlib.figure.Figure at 0x7fb14c3995f8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb14c0a2cf8>,
#  <matplotlib.figure.Figure at 0x7fb148d62ba8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb148ce28d0>)

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
subarray = array[0:2]
for net in subarray:
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(valid)']], label=net[0])
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], label=net[0])
    axs[0].set_ylabel('Error')
    axs[0].legend()
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(valid)']], label=net[0])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']], label=net[0])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
relu = np.min(array[0][1][0][1:, net[1][1]['error(valid)']])
sigmoid = np.min(array[1][1][0][1:, net[1][1]['error(valid)']])
relu2 = np.min(array[2][1][0][1:, net[1][1]['error(valid)']])
relu3 = np.min(array[3][1][0][1:, net[1][1]['error(valid)']])
relu4 = np.min(array[4][1][0][1:, net[1][1]['error(valid)']])

(sigmoid, relu, relu2, relu3, relu4)
# Out:
# (0.085808546107419781,
#  0.086169328382585203,
#  0.087003873168987222,
#  0.08743512205255391,
#  0.090196624390888894)

# %%
relu = np.min(array[0][1][0][1:, net[1][1]['acc(valid)']])
sigmoid = np.min(array[1][1][0][1:, net[1][1]['acc(valid)']])
relu2 = np.min(array[2][1][0][1:, net[1][1]['acc(valid)']])
relu3 = np.min(array[3][1][0][1:, net[1][1]['acc(valid)']])
relu4 = np.min(array[4][1][0][1:, net[1][1]['acc(valid)']])

(sigmoid, relu, relu2, relu3, relu4)
# Out:
# (0.93410000000000037,
#  0.96479999999999966,
#  0.96419999999999983,
#  0.95929999999999993,
#  0.95849999999999946)

# %%
file_name = 'hiddenLayers'
fileObject = open(file_name,'rb');
length = 21
array2 = []
for i in range(0,length):
    array2.append(pickle.load(fileObject));
fileObject.close()

sigmoids = array2[0:7]
leakyRelu = array2[7:14]
selu = array2[14:21]
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">

# %%
plt.close("all")

# %%
sigmoids
# Out:
# [((SigmoidLayer, 2, 'uniform'),
#   (array([[ 2.66550698,  0.10214   ,  2.66577187,  0.1047    ,  0.        ],
#           [ 0.23839859,  0.93094   ,  0.22705438,  0.9341    ,  0.        ],
#           [ 0.17769092,  0.9485    ,  0.1793856 ,  0.9508    ,  0.        ],
#           [ 0.14281096,  0.95862   ,  0.15265993,  0.9576    ,  0.        ],
#           [ 0.11883807,  0.96616   ,  0.13533207,  0.9616    ,  0.        ],
#           [ 0.10312037,  0.97038   ,  0.12392922,  0.9637    ,  0.        ],
#           [ 0.08805697,  0.975     ,  0.11431296,  0.9659    ,  0.        ],
#           [ 0.07860354,  0.97792   ,  0.10914605,  0.9681    ,  0.        ],
#           [ 0.06961577,  0.98094   ,  0.10419481,  0.9694    ,  0.        ],
#           [ 0.06127391,  0.9834    ,  0.09898355,  0.9718    ,  0.        ],
#           [ 0.05597044,  0.98536   ,  0.09673356,  0.972     ,  0.        ],
,
#    <matplotlib.axes._subplots.AxesSubplot at 0x7f355b2a5278>)),
#  ((SigmoidLayer, 7, 'uniform'),
#   (array([[ 2.635169  ,  0.09976   ,  2.63775434,  0.0961    ,  0.        ],
#           [ 2.306007  ,  0.09976   ,  2.30671546,  0.0961    ,  0.        ],
#           [ 2.30551891,  0.11356   ,  2.30793595,  0.1064    ,  0.        ],
#           [ 2.30217177,  0.11356   ,  2.30314103,  0.1064    ,  0.        ],
#           [ 2.3006196 ,  0.11356   ,  2.30162925,  0.1064    ,  0.        ],
#           [ 1.29447329,  0.51772   ,  1.27269407,  0.5223    ,  0.        ],
#           [ 0.87266387,  0.76398   ,  0.85320432,  0.7696    ,  0.        ],
#           [ 0.64144052,  0.81022   ,  0.62302594,  0.8174    ,  0.        ],
#           [ 0.49677717,  0.87786   ,  0.50542383,  0.8783    ,  0.        ],
#           [ 0.28586882,  0.9293    ,  0.30615164,  0.9254    ,  0.        ],
#           [ 0.22151779,  0.94222   ,  0.25809659,  0.9352    ,  0.        ],
#           [ 0.17656194,  0.95342   ,  0.22825665,  0.9418    ,  0.        ],
#           [ 0.15472892,  0.95838   ,  0.21530746,  0.9425    ,  0.        ],
#           [ 0.12506044,  0.9677    ,  0.19759165,  0.9496    ,  0.        ],
#           [ 0.11505654,  0.96934   ,  0.19504144,  0.9474    ,  0.        ],
#           [ 0.10468601,  0.9715    ,  0.19613357,  0.949     ,  0.        ],
#           [ 0.08265082,  0.97908   ,  0.18521031,  0.9539    ,  0.        ],
#           [ 0.08192139,  0.97834   ,  0.1978599 ,  0.9508    ,  0.        ],
#           [ 0.08132551,  0.97782   ,  0.20180874,  0.9512    ,  0.        ],
#           [ 0.05811704,  0.9862    ,  0.19064094,  0.9546    ,  0.        ],
#           [ 0.05306014,  0.98728   ,  0.18811191,  0.9559    ,  0.        ]]),
#    {'acc(train)': 1,
#     'acc(valid)': 3,
#     'error(train)': 0,
#     'error(valid)': 2,
#     'params_penalty': 4},
#    191.33601069450378,
#    <matplotlib.figure.Figure at 0x7f355b56bf60>,
#    <matplotlib.axes._subplots.AxesSubplot at 0x7f355b301208>,
#    <matplotlib.figure.Figure at 0x7f355b1c77b8>,
#    <matplotlib.axes._subplots.AxesSubplot at 0x7f355b13d828>))]

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
subarray = leakyRelu
for net in subarray:
#     axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(valid)']], label=net[0])
#     axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], label=net[0])
    axs[0].set_ylabel('Acc(test)')
    axs[0].legend()
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(valid)']])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']], label=net[0][1])
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
# Out:
# <img src="data:image/png;base64,..." width="800">
# /home/miro/.conda/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
