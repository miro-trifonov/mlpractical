# %%
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
import pickle
# %matplotlib notebook

# %%
file_name = 'exp_conv_1'
file_name2 = 'exp_batch_50'
fileObject2 = open(file_name,'rb');
fileObject3 = open(file_name2,'rb');
length = 1
array = []
for i in range(0,length):
    array.append(pickle.load(fileObject2));
for i in range(0,length):
    array.append(pickle.load(fileObject3));
fileObject2.close()
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">

# %%
array[0][1];

# %%
fig, axs = plt.subplots(2, 1, figsize=(8,8))
# subarray = [array[1]] + [array[3]]
i = 0
this = ["Conv net train", "Batch norm test","Conv net valid " ,"Batch norm valid"]
for net in array:
#     axs[0].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['error(train)']], )
    axs[0].plot(np.arange(1, net[1][0].shape[0])*2, net[1][0][1:, net[1][1]['error(train)']],label=("%s error" % this[i]))
#     axs[2].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']])
    j = i + 2
    print(this[j])
    axs[0].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['error(valid)']], label = ("%s error" % this[j]))
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Error')
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(train)']], label=("%s accuracy" % this[i]))
#     axs[2].plot(np.arange(1, net[1][0].shape[0]) * 5, net[1][0][1:, net[1][1]['acc(train)']])
    axs[1].plot(np.arange(1, net[1][0].shape[0]) * 2, net[1][0][1:, net[1][1]['acc(valid)']], label =("%s accuracy" % this[j]))
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
    axs[0].legend()
    i+= 1
    plt.savefig('conv.pdf'.format("learning_rate"))
# Out:
# <img src="data:image/png;base64,..." width="800">
# Conv net valid
# Batch norm valid

# %%
relu = np.max(array[0][1][0][1:, net[1][1]['acc(valid)']])
sigmoid = np.max(array[1][1][0][1:, net[1][1]['acc(valid)']])
# relu2 = np.max(array[2][1][0][1:, net[1][1]['acc(valid)']])
# relu3 = np.max(array[3][1][0][1:, net[1][1]['acc(valid)']])
# relu4 = np.max(array[6][1][0][1:, net[1][1]['acc(valid)']])

(sigmoid, relu)
# Out:
# (0.83056962025316416, 0.7808860759493671)
